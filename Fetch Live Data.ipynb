# %%
from fyers_apiv3.FyersWebsocket import data_ws
from fyers_apiv3 import fyersModel
from datetime import datetime, timedelta

app_id = open("fyers_appid.txt", 'r').read()
access_token = open("fyers_token.txt", 'r').read()

def onmessage(message):
    """
    Callback function to handle incoming messages from the FyersDataSocket WebSocket.

    Parameters:
        message (dict): The received message from the WebSocket.

    """
    print("Response:", message)


def onerror(message):
    """
    Callback function to handle WebSocket errors.

    Parameters:
        message (dict): The error message received from the WebSocket.


    """
    print("Error:", message)


def onclose(message):
    """
    Callback function to handle WebSocket connection close events.
    """
    print("Connection closed:", message)


def onopen():
    """
    Callback function to subscribe to data type and symbols upon WebSocket connection.

    """
    # Specify the data type and symbols you want to subscribe to
    data_type = "SymbolUpdate"

    # Subscribe to the specified symbols and data type
    symbols = ['MCX:SILVERMIC24FEBFUT']  #['NSE:SBIN-EQ', 'NSE:ADANIENT-EQ']
    fyers.subscribe(symbols=symbols, data_type=data_type)

    # Keep the socket running to receive real-time data
    fyers.keep_running()


# Replace the sample access token with your actual access token obtained from Fyers
access_token = app_id+":"+access_token

# Create a FyersDataSocket instance with the provided parameters
fyers = data_ws.FyersDataSocket(
    access_token=access_token,       # Access token in the format "appid:accesstoken"
    log_path="",                     # Path to save logs. Leave empty to auto-create logs in the current directory.
    litemode=False,                  # Lite mode disabled. Set to True if you want a lite response.
    write_to_file=True,              # Save response in a log file instead of printing it.
    reconnect=True,                  # Enable auto-reconnection to WebSocket on disconnection.
    on_connect=onopen,               # Callback function to subscribe to data upon connection.
    on_close=onclose,                # Callback function to handle WebSocket connection close events.
    on_error=onerror,                # Callback function to handle WebSocket errors.
    on_message=onmessage             # Callback function to handle incoming messages from the WebSocket.
)

# Establish a connection to the Fyers WebSocket
fyers.connect()
# Out:
# Response: {'type': 'cn', 'code': 200, 'message': 'Authentication done', 's': 'ok'}
# Response: {'type': 'ful', 'code': 200, 'message': 'Full Mode On', 's': 'ok'}
# Response: {'type': 'sub', 'code': 200, 'message': 'Subscribed', 's': 'ok'}
# Response: {'ltp': 72333.0, 'vol_traded_today': 82303, 'last_traded_time': 1705416777, 'exch_feed_time': 1705416779, 'bid_size': 1, 'ask_size': 4, 'bid_price': 72328.0, 'ask_price': 72334.0, 'last_traded_qty': 1, 'tot_buy_qty': 12482, 'tot_sell_qty': 13302, 'avg_trade_price': 72444.09, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -353.0, 'chp': -0.4857}
# Response: {'ltp': 72330.0, 'vol_traded_today': 82322, 'last_traded_time': 1705416784, 'exch_feed_time': 1705416784, 'bid_size': 7, 'ask_size': 1, 'bid_price': 72322.0, 'ask_price': 72328.0, 'last_traded_qty': 1, 'tot_buy_qty': 12417, 'tot_sell_qty': 13304, 'avg_trade_price': 72444.06, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -356.0, 'chp': -0.4898}
# Response: {'ltp': 72330.0, 'vol_traded_today': 82322, 'last_traded_time': 1705416784, 'exch_feed_time': 1705416784, 'bid_size': 2, 'ask_size': 4, 'bid_price': 72325.0, 'ask_price': 72330.0, 'last_traded_qty': 1, 'tot_buy_qty': 12537, 'tot_sell_qty': 13201, 'avg_trade_price': 72444.06, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -356.0, 'chp': -0.4898}
# Response: {'ltp': 72335.0, 'vol_traded_today': 82329, 'last_traded_time': 1705416790, 'exch_feed_time': 1705416791, 'bid_size': 2, 'ask_size': 3, 'bid_price': 72330.0, 'ask_price': 72334.0, 'last_traded_qty': 2, 'tot_buy_qty': 12531, 'tot_sell_qty': 13282, 'avg_trade_price': 72444.05, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -351.0, 'chp': -0.4829}
# Response: {'ltp': 72335.0, 'vol_traded_today': 82329, 'last_traded_time': 1705416790, 'exch_feed_time': 1705416792, 'bid_size': 3, 'ask_size': 3, 'bid_price': 72330.0, 'ask_price': 72334.0, 'last_traded_qty': 2, 'tot_buy_qty': 12532, 'tot_sell_qty': 13282, 'avg_trade_price': 72444.05, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -351.0, 'chp': -0.4829}
# Response: {'ltp': 72329.0, 'vol_traded_today': 82352, 'last_traded_time': 1705416795, 'exch_feed_time': 1705416795, 'bid_size': 7, 'ask_size': 1, 'bid_price': 72327.0, 'ask_price': 72330.0, 'last_traded_qty': 2, 'tot_buy_qty': 12501, 'tot_sell_qty': 13321, 'avg_trade_price': 72444.02, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -357.0, 'chp': -0.4912}
# Response: {'ltp': 72322.0, 'vol_traded_today': 82366, 'last_traded_time': 1705416795, 'exch_feed_time': 1705416798, 'bid_size': 2, 'ask_size': 6, 'bid_price': 72313.0, 'ask_price': 72326.0, 'last_traded_qty': 7, 'tot_buy_qty': 12451, 'tot_sell_qty': 13352, 'avg_trade_price': 72444.0, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -364.0, 'chp': -0.5008}
# Response: {'ltp': 72325.0, 'vol_traded_today': 82386, 'last_traded_time': 1705416800, 'exch_feed_time': 1705416801, 'bid_size': 3, 'ask_size': 5, 'bid_price': 72315.0, 'ask_price': 72324.0, 'last_traded_qty': 1, 'tot_buy_qty': 12460, 'tot_sell_qty': 13372, 'avg_trade_price': 72443.97, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -361.0, 'chp': -0.4967}
# Response: {'ltp': 72324.0, 'vol_traded_today': 82387, 'last_traded_time': 1705416801, 'exch_feed_time': 1705416800, 'bid_size': 2, 'ask_size': 6, 'bid_price': 72314.0, 'ask_price': 72325.0, 'last_traded_qty': 1, 'tot_buy_qty': 12459, 'tot_sell_qty': 13366, 'avg_trade_price': 72443.97, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -362.0, 'chp': -0.498}
# Response: {'ltp': 72313.0, 'vol_traded_today': 82394, 'last_traded_time': 1705416803, 'exch_feed_time': 1705416804, 'bid_size': 2, 'ask_size': 5, 'bid_price': 72314.0, 'ask_price': 72325.0, 'last_traded_qty': 2, 'tot_buy_qty': 12404, 'tot_sell_qty': 13287, 'avg_trade_price': 72443.95, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -373.0, 'chp': -0.5132}
# Response: {'ltp': 72326.0, 'vol_traded_today': 82402, 'last_traded_time': 1705416809, 'exch_feed_time': 1705416809, 'bid_size': 30, 'ask_size': 9, 'bid_price': 72323.0, 'ask_price': 72333.0, 'last_traded_qty': 1, 'tot_buy_qty': 12473, 'tot_sell_qty': 13341, 'avg_trade_price': 72443.94, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -360.0, 'chp': -0.4953}
# Response: {'ltp': 72324.0, 'vol_traded_today': 82427, 'last_traded_time': 1705416810, 'exch_feed_time': 1705416810, 'bid_size': 1, 'ask_size': 33, 'bid_price': 72323.0, 'ask_price': 72335.0, 'last_traded_qty': 5, 'tot_buy_qty': 12451, 'tot_sell_qty': 13364, 'avg_trade_price': 72443.91, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -362.0, 'chp': -0.498}
# Response: {'ltp': 72324.0, 'vol_traded_today': 82427, 'last_traded_time': 1705416810, 'exch_feed_time': 1705416812, 'bid_size': 6, 'ask_size': 2, 'bid_price': 72320.0, 'ask_price': 72333.0, 'last_traded_qty': 5, 'tot_buy_qty': 12470, 'tot_sell_qty': 13370, 'avg_trade_price': 72443.91, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -362.0, 'chp': -0.498}
# Response: {'ltp': 72322.0, 'vol_traded_today': 82428, 'last_traded_time': 1705416813, 'exch_feed_time': 1705416816, 'bid_size': 2, 'ask_size': 4, 'bid_price': 72320.0, 'ask_price': 72332.0, 'last_traded_qty': 1, 'tot_buy_qty': 12465, 'tot_sell_qty': 13374, 'avg_trade_price': 72443.91, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -364.0, 'chp': -0.5008}
# Response: {'ltp': 72320.0, 'vol_traded_today': 82432, 'last_traded_time': 1705416819, 'exch_feed_time': 1705416819, 'bid_size': 5, 'ask_size': 40, 'bid_price': 72318.0, 'ask_price': 72320.0, 'last_traded_qty': 2, 'tot_buy_qty': 12453, 'tot_sell_qty': 13420, 'avg_trade_price': 72443.9, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -366.0, 'chp': -0.5035}
# Response: {'ltp': 72320.0, 'vol_traded_today': 82432, 'last_traded_time': 1705416819, 'exch_feed_time': 1705416819, 'bid_size': 3, 'ask_size': 40, 'bid_price': 72318.0, 'ask_price': 72320.0, 'last_traded_qty': 2, 'tot_buy_qty': 12449, 'tot_sell_qty': 13424, 'avg_trade_price': 72443.9, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -366.0, 'chp': -0.5035}
# Response: {'ltp': 72320.0, 'vol_traded_today': 82434, 'last_traded_time': 1705416821, 'exch_feed_time': 1705416822, 'bid_size': 2, 'ask_size': 38, 'bid_price': 72318.0, 'ask_price': 72320.0, 'last_traded_qty': 1, 'tot_buy_qty': 12445, 'tot_sell_qty': 13431, 'avg_trade_price': 72443.9, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -366.0, 'chp': -0.5035}
# Response: {'ltp': 72297.0, 'vol_traded_today': 82530, 'last_traded_time': 1705416824, 'exch_feed_time': 1705416825, 'bid_size': 2, 'ask_size': 8, 'bid_price': 72292.0, 'ask_price': 72293.0, 'last_traded_qty': 1, 'tot_buy_qty': 12320, 'tot_sell_qty': 13614, 'avg_trade_price': 72443.74, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -389.0, 'chp': -0.5352}
# Response: {'ltp': 72280.0, 'vol_traded_today': 82556, 'last_traded_time': 1705416829, 'exch_feed_time': 1705416829, 'bid_size': 3, 'ask_size': 4, 'bid_price': 72280.0, 'ask_price': 72289.0, 'last_traded_qty': 1, 'tot_buy_qty': 12308, 'tot_sell_qty': 13499, 'avg_trade_price': 72443.69, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -406.0, 'chp': -0.5586}
# Response: {'ltp': 72282.0, 'vol_traded_today': 82558, 'last_traded_time': 1705416830, 'exch_feed_time': 1705416833, 'bid_size': 1, 'ask_size': 4, 'bid_price': 72281.0, 'ask_price': 72290.0, 'last_traded_qty': 1, 'tot_buy_qty': 12361, 'tot_sell_qty': 13468, 'avg_trade_price': 72443.68, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -404.0, 'chp': -0.5558}
# Response: {'ltp': 72282.0, 'vol_traded_today': 82558, 'last_traded_time': 1705416830, 'exch_feed_time': 1705416830, 'bid_size': 1, 'ask_size': 4, 'bid_price': 72281.0, 'ask_price': 72290.0, 'last_traded_qty': 1, 'tot_buy_qty': 12334, 'tot_sell_qty': 13468, 'avg_trade_price': 72443.68, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -404.0, 'chp': -0.5558}
# Response: {'ltp': 72290.0, 'vol_traded_today': 82559, 'last_traded_time': 1705416833, 'exch_feed_time': 1705416835, 'bid_size': 1, 'ask_size': 3, 'bid_price': 72281.0, 'ask_price': 72290.0, 'last_traded_qty': 1, 'tot_buy_qty': 12357, 'tot_sell_qty': 13466, 'avg_trade_price': 72443.68, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -396.0, 'chp': -0.5448}
# Response: {'ltp': 72298.0, 'vol_traded_today': 82564, 'last_traded_time': 1705416838, 'exch_feed_time': 1705416839, 'bid_size': 2, 'ask_size': 2, 'bid_price': 72286.0, 'ask_price': 72298.0, 'last_traded_qty': 1, 'tot_buy_qty': 12349, 'tot_sell_qty': 13464, 'avg_trade_price': 72443.67, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -388.0, 'chp': -0.5338}
# Response: {'ltp': 72298.0, 'vol_traded_today': 82564, 'last_traded_time': 1705416838, 'exch_feed_time': 1705416838, 'bid_size': 5, 'ask_size': 6, 'bid_price': 72282.0, 'ask_price': 72294.0, 'last_traded_qty': 1, 'tot_buy_qty': 12362, 'tot_sell_qty': 13509, 'avg_trade_price': 72443.67, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -388.0, 'chp': -0.5338}
# Response: {'ltp': 72298.0, 'vol_traded_today': 82564, 'last_traded_time': 1705416838, 'exch_feed_time': 1705416841, 'bid_size': 5, 'ask_size': 4, 'bid_price': 72283.0, 'ask_price': 72297.0, 'last_traded_qty': 1, 'tot_buy_qty': 12360, 'tot_sell_qty': 13478, 'avg_trade_price': 72443.67, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -388.0, 'chp': -0.5338}
# Response: {'ltp': 72293.0, 'vol_traded_today': 82569, 'last_traded_time': 1705416847, 'exch_feed_time': 1705416847, 'bid_size': 10, 'ask_size': 5, 'bid_price': 72282.0, 'ask_price': 72294.0, 'last_traded_qty': 1, 'tot_buy_qty': 12302, 'tot_sell_qty': 13522, 'avg_trade_price': 72443.66, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -393.0, 'chp': -0.5407}
# Response: {'ltp': 72273.0, 'vol_traded_today': 82609, 'last_traded_time': 1705416848, 'exch_feed_time': 1705416847, 'bid_size': 1, 'ask_size': 3, 'bid_price': 72272.0, 'ask_price': 72278.0, 'last_traded_qty': 1, 'tot_buy_qty': 12234, 'tot_sell_qty': 13604, 'avg_trade_price': 72443.58, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -413.0, 'chp': -0.5682}
# Response: {'ltp': 72279.0, 'vol_traded_today': 82620, 'last_traded_time': 1705416851, 'exch_feed_time': 1705416852, 'bid_size': 1, 'ask_size': 27, 'bid_price': 72272.0, 'ask_price': 72279.0, 'last_traded_qty': 5, 'tot_buy_qty': 12293, 'tot_sell_qty': 13538, 'avg_trade_price': 72443.56, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -407.0, 'chp': -0.5599}
# Response: {'ltp': 72279.0, 'vol_traded_today': 82621, 'last_traded_time': 1705416855, 'exch_feed_time': 1705416855, 'bid_size': 1, 'ask_size': 26, 'bid_price': 72273.0, 'ask_price': 72279.0, 'last_traded_qty': 1, 'tot_buy_qty': 12302, 'tot_sell_qty': 13544, 'avg_trade_price': 72443.56, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -407.0, 'chp': -0.5599}
# Response: {'ltp': 72280.0, 'vol_traded_today': 82622, 'last_traded_time': 1705416855, 'exch_feed_time': 1705416855, 'bid_size': 1, 'ask_size': 26, 'bid_price': 72278.0, 'ask_price': 72280.0, 'last_traded_qty': 1, 'tot_buy_qty': 12312, 'tot_sell_qty': 13544, 'avg_trade_price': 72443.56, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -406.0, 'chp': -0.5586}
# Response: {'ltp': 72288.0, 'vol_traded_today': 82626, 'last_traded_time': 1705416858, 'exch_feed_time': 1705416859, 'bid_size': 7, 'ask_size': 3, 'bid_price': 72279.0, 'ask_price': 72288.0, 'last_traded_qty': 3, 'tot_buy_qty': 12363, 'tot_sell_qty': 13446, 'avg_trade_price': 72443.55, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -398.0, 'chp': -0.5476}
# Response: {'ltp': 72288.0, 'vol_traded_today': 82626, 'last_traded_time': 1705416858, 'exch_feed_time': 1705416858, 'bid_size': 7, 'ask_size': 30, 'bid_price': 72279.0, 'ask_price': 72290.0, 'last_traded_qty': 3, 'tot_buy_qty': 12374, 'tot_sell_qty': 13440, 'avg_trade_price': 72443.55, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -398.0, 'chp': -0.5476}
# Response: {'ltp': 72288.0, 'vol_traded_today': 82626, 'last_traded_time': 1705416858, 'exch_feed_time': 1705416860, 'bid_size': 2, 'ask_size': 33, 'bid_price': 72280.0, 'ask_price': 72292.0, 'last_traded_qty': 3, 'tot_buy_qty': 12417, 'tot_sell_qty': 13501, 'avg_trade_price': 72443.55, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -398.0, 'chp': -0.5476}
# Response: {'ltp': 72292.0, 'vol_traded_today': 82641, 'last_traded_time': 1705416863, 'exch_feed_time': 1705416865, 'bid_size': 7, 'ask_size': 1, 'bid_price': 72279.0, 'ask_price': 72288.0, 'last_traded_qty': 1, 'tot_buy_qty': 12421, 'tot_sell_qty': 13547, 'avg_trade_price': 72443.52, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -394.0, 'chp': -0.5421}
# Response: {'ltp': 72279.0, 'vol_traded_today': 82648, 'last_traded_time': 1705416866, 'exch_feed_time': 1705416866, 'bid_size': 2, 'ask_size': 1, 'bid_price': 72279.0, 'ask_price': 72288.0, 'last_traded_qty': 5, 'tot_buy_qty': 12416, 'tot_sell_qty': 13549, 'avg_trade_price': 72443.51, 'low_price': 72211.0, 'high_price': 72675.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 72546.0, 'prev_close_price': 72686.0, 'type': 'sf', 'symbol': 'MCX:SILVERMIC24FEBFUT', 'ch': -407.0, 'chp': -0.5599}
